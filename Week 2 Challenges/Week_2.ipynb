# %% [markdown]
# # Week 2 Challenges: Data Manipulation and Working with Web Services

# %% [markdown]
# ## Challenge No 1:
#
# 1. Using a Dictionary, create a dataframe (table), with at least 4 columns and more than 100 rows. How come you can create this among data from scratch without defining every single row of data?
# 2. Using the appropriate method, create a new DataFrame containing only the first 30 rows and the first 3 columns of the original DataFrame. Name this new DataFrame subset_df.
# 3. Using the appropriate method, filter the rows from the original dataframe where a numerical attribute(column) is greater than a particular numerical value, and find another categorical attribute that is equal to a specific string or text. Name this new DataFrame filtered_df.
# 4. Check this website https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html and apply the methods, mean, standard deviation, group_by to run fundamental statistical analysis of your created data frame.
# 5. Make sure you comment on your code and describe how you are manipulating the data.

# %%
# import relevant libraries

import numpy as np
import pandas as pd

# %%
#Create four arrays arrays
c1 = range(1, 101) #create a list of integers from 1 to 100
c2 = np.random.randint(0, 1000, 100) #100 random values from 1 to 1000
c3 = np.random.randint(0, 1000, 100) #100 random values from 1 to 1000
c4 = np.random.randint(0, 1000, 100) #100 random values from 1 to 1000
#Create data frame
d1 = pd.DataFrame({'c1':c1,'c2':c2, 'c3' : c3, 'c4': c4})  #the curly brackets indicate a dictionary
d1.head()
print(len(d1))
# Out:
# 100

# %%
# use iloc function to subset 30 rows and 3 columns by index

subset_df = d1.iloc[:31, :4]
subset_df.head()
print(len(subset_df))
# Out:
# 31

# %%
# filtering rows where the value of c2 is more than 500

filtered_df = subset_df.query('c2 > 500')
filtered_df.head()
# Out:
#    c1   c2   c3   c4
# 0   1  882  752  484
# 1   2  726  657  511
# 3   4  779  478  796
# 5   6  665  153  646
# 6   7  610  337  458

# %%
# calculate mean
filtered_df.mean()
# Out:
# c1     14.000000
# c2    710.461538
# c3    441.923077
# c4    445.307692
# dtype: float64

# %% [markdown]
# ## Challenge No 2:
#
# **Part No 1:**
#
# 1. Using the same workflow previously described, now calculate the clustered areas for the GeoPandasDataFrame `gdf_bikes_end`
# 2. Make sure you don't have any NaN in your columns, add a CRS, clean up the unnecessary attributes, calculate the cluster values, and plot a map of 4 calculated clusters for the return locations.

# %%
# import libraries

import requests
import pandas as pd
import geopandas as gpd

# %%
# fetch bike rentals data from the API

url_bikes = "https://api.glasgow.gov.uk/mobility/v1/get_rentals?startDate=2022-05-01&endDate=2023-05-01"
# Making the query to the web server, using the Get method from the requests library 
response = requests.get(url_bikes)
response
# Out:
# <Response [200]>

# %%
# store data in json format
data = response.json()
data

# save the data without metadata into a variable
rental_data = data['data']

# convert into pandas dataframe
rental_pd = pd.DataFrame(rental_data)

rental_pd.head()
# Out:
#                     created                   updated cityId  bikeId  \
# 0  2022-10-21T13:09:57.926Z  2022-10-21T13:09:57.926Z    237  116870
# 1  2022-10-21T13:09:57.975Z  2022-10-21T13:09:57.975Z    237  143384
# 2  2022-10-21T13:09:58.026Z  2022-10-21T13:09:58.026Z    237  129744
# 3  2022-10-21T13:09:58.076Z  2022-10-21T13:09:58.076Z    237  143168
# 4  2022-10-21T13:09:58.126Z  2022-10-21T13:09:58.126Z    237  143248
#
#               startDate startPlaceId startPlaceCityId  \
# 0  2022-05-01T00:01:40Z       264299              237
# 1  2022-05-01T00:04:17Z     28521547              237
# 2  2022-05-01T00:04:24Z       266171              237
# 3  2022-05-01T00:04:29Z       349455              237
# 4  2022-05-01T00:04:40Z       349455              237
#
#                             startPlaceName  startPlaceStationNumber  \
# 0                    ELECTRIC - Broomielaw                   8413.0
# 1                        King Street South                   8230.0
# 2  University of Glasgow (East) - ELECTRIC                   8435.0
# 3       ELECTRIC - Cessnock Subway Station                   8444.0
# 4       ELECTRIC - Cessnock Subway Station                   8444.0
#
#    startPlaceLat  ...  endPlaceCityId endChannelId  \
# 0      55.856600  ...             237          381
# 1      55.855860  ...             237          381
# 2      55.871763  ...             237          381
# 3      55.851918  ...             237          381
# 4      55.851918  ...             237          381
#
#                                         endPlaceName endPlaceStationNumber  \
# 0                              ELECTRIC - Broomielaw                8413.0
# 1  Alexandra Park (south entrance) Alexandra Para...                8457.0
# 2                         Botanic Gardens - ELECTRIC                8417.0
# 3                 ELECTRIC - Cessnock Subway Station                8444.0
# 4                         ELECTRIC - St Enoch Square                8410.0
#
#   endPlaceLat endPlaceLong durationSeconds  isInvalid  price  isEbike
# 0   55.856600    -4.263521              56      False    2.0     True
# 1   55.863128    -4.210282            1097      False    1.0    False
# 2   55.878278    -4.288487             344      False    1.0    False
# 3   55.851918    -4.294490           10400      False    6.0    False
# 4   55.856829    -4.255292            4611      False    3.0    False
#
# [5 rows x 24 columns]

# %%
# clean data - drop missing values and subset attributes

clean_rental_pd = rental_pd.dropna(subset=['startPlaceLat', 'startPlaceLong', 'endPlaceLat','endPlaceLong'])

# create two separate datasets for start points and end points

#gdf_bikes_start = gpd.GeoDataFrame(clean_rental_pd, geometry=gpd.points_from_xy(clean_rental_pd['startPlaceLong'], clean_rental_pd['startPlaceLat']))
gdf_bikes_end = gpd.GeoDataFrame(clean_rental_pd, geometry=gpd.points_from_xy(clean_rental_pd['endPlaceLong'], clean_rental_pd['endPlaceLat']))

# %%
# set a CRS
gdf_bikes_end = gdf_bikes_end.set_crs("EPSG:4326")

# %%
# explore dataset in an interactive map
gdf_bikes_end.explore()

# %% [markdown]
# ### Map screenshot
#
# ![Map](map1.png)

# %%
gdf_bikes_end.head()
# Out:
#                     created                   updated cityId  bikeId  \
# 0  2022-10-21T13:09:57.926Z  2022-10-21T13:09:57.926Z    237  116870
# 1  2022-10-21T13:09:57.975Z  2022-10-21T13:09:57.975Z    237  143384
# 2  2022-10-21T13:09:58.026Z  2022-10-21T13:09:58.026Z    237  129744
# 3  2022-10-21T13:09:58.076Z  2022-10-21T13:09:58.076Z    237  143168
# 4  2022-10-21T13:09:58.126Z  2022-10-21T13:09:58.126Z    237  143248
#
#               startDate startPlaceId startPlaceCityId  \
# 0  2022-05-01T00:01:40Z       264299              237
# 1  2022-05-01T00:04:17Z     28521547              237
# 2  2022-05-01T00:04:24Z       266171              237
# 3  2022-05-01T00:04:29Z       349455              237
# 4  2022-05-01T00:04:40Z       349455              237
#
#                             startPlaceName  startPlaceStationNumber  \
# 0                    ELECTRIC - Broomielaw                   8413.0
# 1                        King Street South                   8230.0
# 2  University of Glasgow (East) - ELECTRIC                   8435.0
# 3       ELECTRIC - Cessnock Subway Station                   8444.0
# 4       ELECTRIC - Cessnock Subway Station                   8444.0
#
#    startPlaceLat  ...  endChannelId  \
# 0      55.856600  ...           381
# 1      55.855860  ...           381
# 2      55.871763  ...           381
# 3      55.851918  ...           381
# 4      55.851918  ...           381
#
#                                         endPlaceName endPlaceStationNumber  \
# 0                              ELECTRIC - Broomielaw                8413.0
# 1  Alexandra Park (south entrance) Alexandra Para...                8457.0
# 2                         Botanic Gardens - ELECTRIC                8417.0
# 3                 ELECTRIC - Cessnock Subway Station                8444.0
# 4                         ELECTRIC - St Enoch Square                8410.0
#
#   endPlaceLat endPlaceLong durationSeconds isInvalid  price  isEbike  \
# 0   55.856600    -4.263521              56     False    2.0     True
# 1   55.863128    -4.210282            1097     False    1.0    False
# 2   55.878278    -4.288487             344     False    1.0    False
# 3   55.851918    -4.294490           10400     False    6.0    False
# 4   55.856829    -4.255292            4611     False    3.0    False
#
#                     geometry
# 0  POINT (-4.26352 55.85660)
# 1  POINT (-4.21028 55.86313)
# 2  POINT (-4.28849 55.87828)
# 3  POINT (-4.29449 55.85192)
# 4  POINT (-4.25529 55.85683)
#
# [5 rows x 25 columns]

# %%
# further subset columns

keep_cols = [
    "endDate",
    "endPlaceId",
    "endPlaceName",
    "durationSeconds",
    "isInvalid",
    "price",
    "isEbike",
    "endPlaceLat",
    "endPlaceLong",
    "geometry",
]

gdf_bikes_end = gdf_bikes_end[keep_cols]
gdf_bikes_end.head()
# Out:
#                 endDate endPlaceId  \
# 0  2022-05-01T00:02:36Z     264299
# 1  2022-05-01T00:22:34Z    3812776
# 2  2022-05-01T00:10:08Z     264302
# 3  2022-05-01T02:57:49Z     349455
# 4  2022-05-01T01:21:31Z     264295
#
#                                         endPlaceName  durationSeconds  \
# 0                              ELECTRIC - Broomielaw               56
# 1  Alexandra Park (south entrance) Alexandra Para...             1097
# 2                         Botanic Gardens - ELECTRIC              344
# 3                 ELECTRIC - Cessnock Subway Station            10400
# 4                         ELECTRIC - St Enoch Square             4611
#
#    isInvalid  price  isEbike  endPlaceLat  endPlaceLong  \
# 0      False    2.0     True    55.856600     -4.263521
# 1      False    1.0    False    55.863128     -4.210282
# 2      False    1.0    False    55.878278     -4.288487
# 3      False    6.0    False    55.851918     -4.294490
# 4      False    3.0    False    55.856829     -4.255292
#
#                     geometry
# 0  POINT (-4.26352 55.85660)
# 1  POINT (-4.21028 55.86313)
# 2  POINT (-4.28849 55.87828)
# 3  POINT (-4.29449 55.85192)
# 4  POINT (-4.25529 55.85683)

# %%
# change to more suitable data types

gdf_bikes_end.endPlaceId = gdf_bikes_end.endPlaceId.astype(int)
gdf_bikes_end.endPlaceName = gdf_bikes_end.endPlaceName.astype(str)
gdf_bikes_end['endDate'] = pd.to_datetime(gdf_bikes_end['endDate'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
# obtain 4 cluster areas

from sklearn.cluster import KMeans
num_clusters = 4

kmeans_collection = KMeans(n_clusters=num_clusters, random_state=42)
gdf_bikes_end['kmeans_cluster'] = kmeans_collection.fit_predict(gdf_bikes_end[['endPlaceLong', 'endPlaceLat']])

# %%
# create map of 4 cluster areas

import leafmap

m = leafmap.Map(center=(55.860166, -4.257505),
                zoom=12,
                draw_control=False,
                measure_control=False,
                fullscreen_control=False,
                attribution_control=True,
                   
               )

m.add_basemap("CartoDB.Positron")
m.add_data(
    gdf_bikes_end,
    column='kmeans_cluster',
    legend_title='Clusters',
    cmap='Set1',
    k=4,
)

#Ploting the map
m
# Out:
# Map(center=[55.860166, -4.257505], controls=(AttributionControl(options=['position', 'prefix'], position='bott…

# %% [markdown]
# **Part No 2:**
#
# 1. Using the Glasglow Open Data API ( Transit) https://developer.glasgow.gov.uk/api-details#api=traffic&operation=traffic-sensor-locations fetch all the sensor locations in the city.
# 2. Map the sensor
# 3. Find the WorkingZones and Calculate/Map the areas with more and fewer sensors distributed in the city.
# 4. You will need:
#    * Get two separate Geopandas DataFrames, one for the traffic sensors and another one for the WorkingZones.
#    * Using `sJoin` ( Spatial Join) https://geopandas.org/en/stable/docs/reference/api/geopandas.sjoin.html
#    calculate the overlay of sensors and polygons.
#    * Using group_by https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html to count the number of sensors per WorkingZone
#    * Make sure you add the counts into the WorkingZone polygons of Glasgow so you can create a map of Zones with more and fewer traffic sensors.
#    * Of course, you will need extra steps where you manipulate the data and extract what you need, for instance, clipping the Working Zones only for Glasgow.
# 5. Make sure you comment on your code and describe how you are manipulating the data.

# %%
# fetch bike rentals data from the API
url_sensors = "https://api.glasgow.gov.uk/traffic/v1/movement/sites"
# Making the query to the web server, using the Get method from the requests library 
response = requests.get(url_sensors)
response
# Out:
# <Response [200]>

# %%
sensor_data = response.json()
sensor_data
# Out:
# [{'siteId': 'GH020A_B',
#   'from': {'description': 'Gallowgate west to Sword St',
#    'lat': '55.8543754827825',
#    'long': '-4.217259197086495'},
#   'to': {'description': 'Gallowgate west to Sword St',
#    'lat': '55.854434529999814',
#    'long': '-4.216974959509279'}},
#  {'siteId': 'GJ3301_D',
#   'from': {'description': 'Carmunnock Rd southbound',
#    'lat': '55.821736212748405',
#    'long': '-4.2561270616272875'},
#   'to': {'description': 'Carmunnock Rd southbound',
#    'lat': '55.82105417976632',
#    'long': '-4.25607160697339'}},
#  {'siteId': 'GH020A_A',
#   'from': {'description': 'Gallowgate east to Sword St',
#    'lat': '55.85539015389372',
#    'long': '-4.225769520669405'},
#   'to': {'description': 'Gallowgate east to Sword St',
#    'lat': '55.85526881737797',
#    'long': '-4.2260182328994995'}},
#  {'siteId': 'GJ3301_C',
#   'from': {'description': 'Carmunnock Rd northbound to Kings Park Avenue',
#    'lat': '55.81925458152306',
#    'long': '-4.255696036412074'},
#   'to': {'description': 'Carmunnock Rd northbound to Kings Park Avenue',
#    'lat': '55.81849086854625',
#    'long': '-4.255683756017223'}},
#  {'siteId': 'GJ3301_B',
#   'from': {'description': 'Kings Park Ave westbound to Carmunnock Rd',
#    'lat': '55.820288451422314',
#    'long': '-4.250775113480551'},
#   'to': {'description': 'Kings Park Ave westbound to Carmunnock Rd',
#    'lat': '55.82016283016515',
#    'long': '-4.2502729750640285'}},
#  {'siteId': 'GJ3301_A',
#   'from': {'description': 'Kings Park Rd southbound',
#    'lat': '55.82321777097949',
#    'long': '-4.258160608689249'},
#   'to': {'description': 'Kings Park Rd southbound',
#    'lat': '55.82410688116023',
#    'long': '-4.258196175251756'}},
#  {'siteId': 'GC2381_T',
#   'from': {'description': 'Bulldale Road',
#    'lat': '55.88630723491306',
#    'long': '-4.376194906434908'},
#   'to': {'description': 'Bulldale Road',
#    'lat': '55.886899038949245',
#    'long': '-4.3753355419780835'}},
#  {'siteId': 'GC2381_S',
#   'from': {'description': 'Dumbarton Road Outbound to Bulldale Rd.',
#    'lat': '55.88563301564599',
#    'long': '-4.372475677796264'},
#   'to': {'description': 'Dumbarton Road Outbound to Bulldale Rd.',
#    'lat': '55.88540387234871',
#    'long': '-4.371774067792365'}},
#  {'siteId': 'GC2381_R',
#   'from': {'description': 'Dumbarton Road inbound to Bulldale St',
#    'lat': '55.88791083146969',
#    'long': '-4.3778601932779795'},
#   'to': {'description': 'Dumbarton Road inbound to Bulldale St',
#    'lat': '55.88820586620821',
#    'long': '-4.378405994326701'}},
#  {'siteId': 'GD2701_D',
#   'from': {'description': 'Shiskine Drive',
#    'lat': '55.89713453859071',
#    'long': '-4.29825305864195'},
#   'to': {'description': 'Shiskine Drive',
#    'lat': '55.89670336618549',
#    'long': '-4.299203285213263'}},
#  {'siteId': 'GF0301_S',
#   'from': {'description': 'Royston Rd w/b',
#    'lat': '55.87871919955157',
#    'long': '-4.191340047273297'},
#   'to': {'description': 'Royston Rd w/b',
#    'lat': '55.87839021402277',
#    'long': '-4.194167303027818'}},
#  {'siteId': 'GD2701_B',
#   'from': {'description': 'Maryhill Road outbound towards Shiskine Drive',
#    'lat': '55.89515227975689',
#    'long': '-4.298039841472587'},
#   'to': {'description': 'Maryhill Road outbound towards Shiskine Drive',
#    'lat': '55.89394772975637',
#    'long': '-4.2970889096571705'}},
#  {'siteId': 'GD2701_A',
#   'from': {'description': 'Maryhill Road inbound to Shiskine Drive',
#    'lat': '55.89918876489169',
#    'long': '-4.302309747084052'},
#   'to': {'description': 'Maryhill Road inbound to Shiskine Drive',
#    'lat': '55.89916542948992',
#    'long': '-4.302596303354128'}},
#  {'siteId': 'GL265A_L',
#   'from': {'description': 'Pacific Dr eastbound',
#    'lat': '55.856827323061815',
#    'long': '-4.289959555824773'},
#   'to': {'description': 'Pacific Dr eastbound',
#    'lat': '55.85685847943426',
#    'long': '-4.290217055996317'}},
#  {'siteId': 'GF0301_D',
#   'from': {'description': 'Royston Rd e/b to Robroyston Rd',
#    'lat': '55.87810851407745',
#    'long': '-4.190810017915082'},
#   'to': {'description': 'Royston Rd e/b to Robroyston Rd',
#    'lat': '55.878817107346244',
#    'long': '-4.191393528638299'}},
#  {'siteId': 'GF0301_C',
#   'from': {'description': 'Royston Rd w/b to Robroyston Rd',
#    'lat': '55.879206944843226',
#    'long': '-4.189688801744091'},
#   'to': {'description': 'Royston Rd w/b to Robroyston Rd',
#    'lat': '55.878817107346244',
#    'long': '-4.191393528638299'}},
#  {'siteId': 'GJ275A_V',
#   'from': {'description': 'Cathcart Rd northbound to Preston St',
#    'lat': '55.83693354635203',
#    'long': '-4.257135210420471'},
#   'to': {'description': 'Cathcart Rd northbound to Preston St',
#    'lat': '55.83687762899016',
#    'long': '-4.25724376518555'}},
#  {'siteId': 'GF0301_B',
#   'from': {'description': 'Langdale St n/b',
#    'lat': '55.87947536584209',
#    'long': '-4.191270748509423'},
#   'to': {'description': 'Langdale St n/b',
#    'lat': '55.878817107346244',
#    'long': '-4.191393528638299'}},
#  {'siteId': 'GC4151_G',
#   'from': {'description': 'On-ramp Westbound to Clydeside Expressway',
#    'lat': '55.86069950889394',
#    'long': '-4.283267802105605'},
#   'to': {'description': 'On-ramp Westbound to Clydeside Expressway',
#    'lat': '55.86038667864348',
#    'long': '-4.2826901232101795'}},
#  {'siteId': 'GC4151_E',
#   'from': {'description': 'Congress Way Northbound Outside to Pointhouse Rd',
#    'lat': '55.85985056415024',
#    'long': '-4.283489648996855'},
#   'to': {'description': 'Congress Way Northbound Outside to Pointhouse Rd',
#    'lat': '55.85935619571898',
#    'long': '-4.283492595662314'}},
#  {'siteId': 'GC4151_C',
#   'from': {'description': 'Congress Way Northbound Inside to Pointhouse Road',
#    'lat': '55.85986733438599',
#    'long': '-4.283554554728458'},
#   'to': {'description': 'Congress Way Northbound Inside to Pointhouse Road',
#    'lat': '55.85935619571898',
#    'long': '-4.283492595662314'}},
#  {'siteId': 'GC4151_A',
#   'from': {'description': 'Stobcross Road Eastbound to Pointhouse Road',
#    'lat': '55.860894822588506',
#    'long': '-4.284365958508686'},
#   'to': {'description': 'Stobcross Road Eastbound to Pointhouse Road',
#    'lat': '55.86038667864348',
#    'long': '-4.2826901232101795'}},
#  {'siteId': 'GH195A_B',
#   'from': {'description': 'London Road westbound to Kent St',
#    'lat': '55.853557522976224',
#    'long': '-4.237120627922957'},
#   'to': {'description': 'London Road westbound to Kent St',
#    'lat': '55.85345791330956',
#    'long': '-4.236667530649426'}},
#  {'siteId': 'GH195A_A',
#   'from': {'description': 'London Road e/b to Kent St.',
#    'lat': '55.854617352151365',
#    'long': '-4.240121510355179'},
#   'to': {'description': 'London Road e/b to Kent St.',
#    'lat': '55.854652939873155',
#    'long': '-4.240634856680875'}},
#  {'siteId': 'GL2651_R',
#   'from': {'description': 'Govan Rd Westbound',
#    'lat': '55.85521346050558',
#    'long': '-4.295536954188497'},
#   'to': {'description': 'Govan Rd Westbound',
#    'lat': '55.85534127437887',
#    'long': '-4.295912000825322'}},
#  {'siteId': 'GB0501_D',
#   'from': {'description': 'Glasgow Bridge SB to Clyde Place',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Glasgow Bridge SB to Clyde Place',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GB0501_A',
#   'from': {'description': 'Clyde Place to Bridge Street eastbound',
#    'lat': '55.8549006837386',
#    'long': '-4.259519372285604'},
#   'to': {'description': 'Clyde Place to Bridge Street eastbound',
#    'lat': '55.85476337655625',
#    'long': '-4.25965520363947'}},
#  {'siteId': 'GA2801_G',
#   'from': {'description': 'Renfrew Street eastbound to Renfield Street offside',
#    'lat': '55.86536126095586',
#    'long': '-4.256626759612004'},
#   'to': {'description': 'Renfrew Street eastbound to Renfield Street offside',
#    'lat': '55.86530300068848',
#    'long': '-4.256863117405453'}},
#  {'siteId': 'GG1101_T',
#   'from': {'description': 'Stepps Road nb from Bellrock St',
#    'lat': '55.86881911962045',
#    'long': '-4.156529385070701'},
#   'to': {'description': 'Stepps Road nb from Bellrock St',
#    'lat': '55.86853966661047',
#    'long': '-4.156577825463893'}},
#  {'siteId': 'GG1101_S',
#   'from': {'description': 'M8 Off-Ramp WB',
#    'lat': '55.869034246707436',
#    'long': '-4.155022867360321'},
#   'to': {'description': 'M8 Off-Ramp WB',
#    'lat': '55.86853966661047',
#    'long': '-4.156577825463893'}},
#  {'siteId': 'GG1101_R',
#   'from': {'description': 'Stepps Road s/b',
#    'lat': '55.86655956269573',
#    'long': '-4.155205423438159'},
#   'to': {'description': 'Stepps Road s/b',
#    'lat': '55.866837896546805',
#    'long': '-4.1552208441953615'}},
#  {'siteId': 'GA2801_B',
#   'from': {'description': 'Renfrew Street westbound',
#    'lat': '55.86507327370817',
#    'long': '-4.254196711337344'},
#   'to': {'description': 'Renfrew Street westbound',
#    'lat': '55.865281629386',
#    'long': '-4.25508782149662'}},
#  {'siteId': 'GA2801_A',
#   'from': {'description': 'Renfrew Street eastbound to Renfield Street nearside',
#    'lat': '55.86540615045904',
#    'long': '-4.256629363666894'},
#   'to': {'description': 'Renfrew Street eastbound to Renfield Street nearside',
#    'lat': '55.86530300068848',
#    'long': '-4.256863117405453'}},
#  {'siteId': 'GK4951_C',
#   'from': {'description': 'Nitshill Road Westbound to Kyleakin Rd',
#    'lat': '55.8016647512256',
#    'long': '-4.328541221239083'},
#   'to': {'description': 'Nitshill Road Westbound to Kyleakin Rd',
#    'lat': '55.80152058659404',
#    'long': '-4.328085826495753'}},
#  {'siteId': 'GK4951_B',
#   'from': {'description': 'Loganswell Road Northbound',
#    'lat': '55.80126196952965',
#    'long': '-4.328453342423473'},
#   'to': {'description': 'Loganswell Road Northbound',
#    'lat': '55.80152058659404',
#    'long': '-4.328085826495753'}},
#  {'siteId': 'GK4951_A',
#   'from': {'description': 'Nitshill Rd Westbound to Loganswell Rd',
#    'lat': '55.801386681125614',
#    'long': '-4.3270885241399295'},
#   'to': {'description': 'Nitshill Rd Westbound to Loganswell Rd',
#    'lat': '55.80152058659404',
#    'long': '-4.328085826495753'}},
#  {'siteId': 'GH3301_F',
#   'from': {'description': 'Dalmarnock Road eastbound LT to Springfield Rd',
#    'lat': '55.84129415766746',
#    'long': '-4.21552392052753'},
#   'to': {'description': 'Dalmarnock Road eastbound LT to Springfield Rd',
#    'lat': '55.84116817560765',
#    'long': '-4.215532724464075'}},
#  {'siteId': 'GH3301_D',
#   'from': {'description': 'Springfield Road southbound',
#    'lat': '55.841390120120394',
#    'long': '-4.214187690112489'},
#   'to': {'description': 'Springfield Road southbound',
#    'lat': '55.84116817560765',
#    'long': '-4.215532724464075'}},
#  {'siteId': 'GH3301_B',
#   'from': {'description': 'Dalmarnock Road westbound to Springfield Rd',
#    'lat': '55.840571955234964',
#    'long': '-4.214205053485609'},
#   'to': {'description': 'Dalmarnock Road westbound to Springfield Rd',
#    'lat': '55.840448271219856',
#    'long': '-4.214086215304658'}},
#  {'siteId': 'GH3301_A',
#   'from': {'description': 'Dalmarnock Road s/b to Springfield Rd',
#    'lat': '55.84249771563329',
#    'long': '-4.2170619200955155'},
#   'to': {'description': 'Dalmarnock Road s/b to Springfield Rd',
#    'lat': '55.84296866880256',
#    'long': '-4.217360281901309'}},
#  {'siteId': 'GC1301_V',
#   'from': {'description': 'Radnor Street to Sauchiehall Street',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Radnor Street to Sauchiehall Street',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GC1301_T',
#   'from': {'description': 'Sauchiehall St to Radnor St.',
#    'lat': '55.86744731675164',
#    'long': '-4.288203198759974'},
#   'to': {'description': 'Sauchiehall St to Radnor St.',
#    'lat': '55.866792607151226',
#    'long': '-4.2886122154594855'}},
#  {'siteId': 'GC1301_S',
#   'from': {'description': 'Kelvin Way',
#    'lat': '55.86659977957889',
#    'long': '-4.287865644847315'},
#   'to': {'description': 'Kelvin Way',
#    'lat': '55.866792607151226',
#    'long': '-4.2886122154594855'}},
#  {'siteId': 'GC1301_R',
#   'from': {'description': 'Argyle Street to Sauchiehall Street',
#    'lat': '55.867603590185865',
#    'long': '-4.290913616788351'},
#   'to': {'description': 'Argyle Street to Sauchiehall Street',
#    'lat': '55.867770895760586',
#    'long': '-4.291099290903467'}},
#  {'siteId': 'GH1001_L',
#   'from': {'description': 'Gallowgate westbound Left Turn into EERR',
#    'lat': '55.85297616211061',
#    'long': '-4.208615665888693'},
#   'to': {'description': 'Gallowgate westbound Left Turn into EERR',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GH1001_J',
#   'from': {'description': 'Gallowgate westbound to roundabout',
#    'lat': '55.85342955763155',
#    'long': '-4.209392334896589'},
#   'to': {'description': 'Gallowgate westbound to roundabout',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GG012A_S',
#   'from': {'description': 'Alexandra Parade',
#    'lat': '55.86364519155325',
#    'long': '-4.217052326028468'},
#   'to': {'description': 'Alexandra Parade',
#    'lat': '55.86340122093017',
#    'long': '-4.216127474018917'}},
#  {'siteId': 'GG012A_R',
#   'from': {'description': 'Alexandra Parade to Armadale',
#    'lat': '55.863287109702064',
#    'long': '-4.213979452532824'},
#   'to': {'description': 'Alexandra Parade to Armadale',
#    'lat': '55.863337171675575',
#    'long': '-4.213694634168933'}},
#  {'siteId': 'GH1001_F',
#   'from': {'description': 'EERR southbound internal to Gallowgate',
#    'lat': '55.85395879914559',
#    'long': '-4.20844774374272'},
#   'to': {'description': 'EERR southbound internal to Gallowgate',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GH1001_E',
#   'from': {'description': 'Biggar St northbound from roundabout',
#    'lat': '55.85407254814759',
#    'long': '-4.209620570161432'},
#   'to': {'description': 'Biggar St northbound from roundabout',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GH1001_D',
#   'from': {'description': 'EERR northbound to Gallowgate',
#    'lat': '55.84870080262547',
#    'long': '-4.209970627469236'},
#   'to': {'description': 'EERR northbound to Gallowgate',
#    'lat': '55.84828321696496',
#    'long': '-4.21020252482527'}},
#  {'siteId': 'GH1001_C',
#   'from': {'description': 'Biggar St southbound',
#    'lat': '55.853719920746975',
#    'long': '-4.208737761770545'},
#   'to': {'description': 'Biggar St southbound',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GH1001_B',
#   'from': {'description': 'Gallowgate west to Holywell St',
#    'lat': '55.85295590290567',
#    'long': '-4.20323019248114'},
#   'to': {'description': 'Gallowgate west to Holywell St',
#    'lat': '55.85129181252292',
#    'long': '-4.197783860320688'}},
#  {'siteId': 'GH1001_A',
#   'from': {'description': 'Gallowgate eastbound from roundabout',
#    'lat': '55.85372297155631',
#    'long': '-4.209568767493034'},
#   'to': {'description': 'Gallowgate eastbound from roundabout',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GK0351_V',
#   'from': {'description': 'Pollokshaws Road inbound to Allison Street',
#    'lat': '55.836412076242205',
#    'long': '-4.270328695468586'},
#   'to': {'description': 'Pollokshaws Road inbound to Allison Street',
#    'lat': '55.836313908834434',
#    'long': '-4.270291031106442'}},
#  {'siteId': 'GD120A_A',
#   'from': {'description': 'Clarence Drive e/b towards Hyndland Road',
#    'lat': '55.87724251706178',
#    'long': '-4.308476302116165'},
#   'to': {'description': 'Clarence Drive e/b towards Hyndland Road',
#    'lat': '55.877285607163955',
#    'long': '-4.3085747862544945'}},
#  {'siteId': 'GK0351_T',
#   'from': {'description': 'Pollokshaws Road outbound to Allison Street',
#    'lat': '55.83798644490389',
#    'long': '-4.268296297205533'},
#   'to': {'description': 'Pollokshaws Road outbound to Allison Street',
#    'lat': '55.83834658561153',
#    'long': '-4.267774245631587'}},
#  {'siteId': 'GK0351_R',
#   'from': {'description': 'Nithsdale Street',
#    'lat': '55.837181815696056',
#    'long': '-4.270501339796873'},
#   'to': {'description': 'Nithsdale Street',
#    'lat': '55.83699328827396',
#    'long': '-4.269516121116813'}},
#  {'siteId': 'GA5051_V',
#   'from': {'description': 'Saltmarket northbound to Greendyke St',
#    'lat': '55.853428168395425',
#    'long': '-4.246683750619731'},
#   'to': {'description': 'Saltmarket northbound to Greendyke St',
#    'lat': '55.85306846618108',
#    'long': '-4.2466949406691255'}},
#  {'siteId': 'GA5051_U',
#   'from': {'description': 'Greendyke Street',
#    'lat': '55.853953189003654',
#    'long': '-4.244509124668593'},
#   'to': {'description': 'Greendyke Street',
#    'lat': '55.85434316247106',
#    'long': '-4.245793874097538'}},
#  {'siteId': 'GB1301_X',
#   'from': {'description': 'Cumberland Street eastbound inside lane',
#    'lat': '55.848179176367914',
#    'long': '-4.254560209726458'},
#   'to': {'description': 'Cumberland Street eastbound inside lane',
#    'lat': '55.84801444539721',
#    'long': '-4.2542311608821075'}},
#  {'siteId': 'GB1301_V',
#   'from': {'description': 'Hospital Street northbound',
#    'lat': '55.84730197077243',
#    'long': '-4.254365627919512'},
#   'to': {'description': 'Hospital Street northbound',
#    'lat': '55.84801444539721',
#    'long': '-4.2542311608821075'}},
#  {'siteId': 'GB1301_T',
#   'from': {'description': 'Hospital Street southbound to Cumberland Street',
#    'lat': '55.849495854109286',
#    'long': '-4.252351907449826'},
#   'to': {'description': 'Hospital Street southbound to Cumberland Street',
#    'lat': '55.84989585166228',
#    'long': '-4.252103459291707'}},
#  {'siteId': 'GH002A_S',
#   'from': {'description': 'Gallowgate East to Kent St',
#    'lat': '55.85560650193221',
#    'long': '-4.238117230640115'},
#   'to': {'description': 'Gallowgate East to Kent St',
#    'lat': '55.85555788324583',
#    'long': '-4.237331491980359'}},
#  {'siteId': 'GA5051_P',
#   'from': {'description': 'Bridgegate',
#    'lat': '55.85487391441056',
#    'long': '-4.246751236943732'},
#   'to': {'description': 'Bridgegate',
#    'lat': '55.85434316247106',
#    'long': '-4.245793874097538'}},
#  {'siteId': 'GH002A_R',
#   'from': {'description': 'Gallowgate West to Kent St',
#    'lat': '55.85532160836109',
#    'long': '-4.235991707786897'},
#   'to': {'description': 'Gallowgate West to Kent St',
#    'lat': '55.85555788324583',
#    'long': '-4.237331491980359'}},
#  {'siteId': 'GB1301_R',
#   'from': {'description': 'Cumberland Street eastbound outside lane',
#    'lat': '55.84814297209656',
#    'long': '-4.254574088234247'},
#   'to': {'description': 'Cumberland Street eastbound outside lane',
#    'lat': '55.84801444539721',
#    'long': '-4.2542311608821075'}},
#  {'siteId': 'GA5051_H',
#   'from': {'description': 'Saltmarket south to Greendyke St',
#    'lat': '55.855894182399155',
#    'long': '-4.24452520424949'},
#   'to': {'description': 'Saltmarket south to Greendyke St',
#    'lat': '55.85593615982788',
#    'long': '-4.244687411447339'}},
#  {'siteId': 'GJ3551_W',
#   'from': {'description': 'Clarkston Road NB R/T towards Old Castle Road',
#    'lat': '55.81738258550053',
#    'long': '-4.262196297709536'},
#   'to': {'description': 'Clarkston Road NB R/T towards Old Castle Road',
#    'lat': '55.81845089826761',
#    'long': '-4.261284553016745'}},
#  {'siteId': 'GJ3551_V',
#   'from': {'description': 'Clarkston Road NB Ahead towards Old Castle Road',
#    'lat': '55.81739068322613',
#    'long': '-4.262244656347269'},
#   'to': {'description': 'Clarkston Road NB Ahead towards Old Castle Road',
#    'lat': '55.81845089826761',
#    'long': '-4.261284553016745'}},
#  {'siteId': 'GJ3551_T',
#   'from': {'description': 'Holmlea Road southbound towards Old Castle Road',
#    'lat': '55.819078294291884',
#    'long': '-4.260889944193136'},
#   'to': {'description': 'Holmlea Road southbound towards Old Castle Road',
#    'lat': '55.81845089826761',
#    'long': '-4.261284553016745'}},
#  {'siteId': 'GC0321_H',
#   'from': {'description': 'Castlebank St to Hayburn St offside',
#    'lat': '55.86811529639363',
#    'long': '-4.309213276354216'},
#   'to': {'description': 'Castlebank St to Hayburn St offside',
#    'lat': '55.868337050735796',
#    'long': '-4.308890778710218'}},
#  {'siteId': 'GC0321_F',
#   'from': {'description': 'Castlebank St eastbound nearside',
#    'lat': '55.86806342207265',
#    'long': '-4.311975403552451'},
#   'to': {'description': 'Castlebank St eastbound nearside',
#    'lat': '55.86841240916866',
#    'long': '-4.31062152360615'}},
#  {'siteId': 'GC0321_D',
#   'from': {'description': 'Link Road to Hayburn St',
#    'lat': '55.86846332374293',
#    'long': '-4.309345826900188'},
#   'to': {'description': 'Link Road to Hayburn St',
#    'lat': '55.868337050735796',
#    'long': '-4.308890778710218'}},
#  {'siteId': 'GC0321_B',
#   'from': {'description': 'Castlebank St to Hayburn St nearside',
#    'lat': '55.86807070822497',
#    'long': '-4.309194645327121'},
#   'to': {'description': 'Castlebank St to Hayburn St nearside',
#    'lat': '55.868337050735796',
#    'long': '-4.308890778710218'}},
#  {'siteId': 'GC0321_A',
#   'from': {'description': 'Castlebank St eastbound offside',
#    'lat': '55.86803618938978',
#    'long': '-4.31198976867953'},
#   'to': {'description': 'Castlebank St eastbound offside',
#    'lat': '55.86841240916866',
#    'long': '-4.31062152360615'}},
#  {'siteId': 'GA1301_P',
#   'from': {'description': 'Broomielaw westbound from KGV Bridge',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Broomielaw westbound from KGV Bridge',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GA1301_G',
#   'from': {'description': 'York St R/T from Broomielaw',
#    'lat': '55.85706130313036',
#    'long': '-4.262744781578143'},
#   'to': {'description': 'York St R/T from Broomielaw',
#    'lat': '55.856875703704084',
#    'long': '-4.262574198531883'}},
#  {'siteId': 'GL1151_D',
#   'from': {'description': 'Broomloan Road southbound',
#    'lat': '55.850616992734636',
#    'long': '-4.311578020227955'},
#   'to': {'description': 'Broomloan Road southbound',
#    'lat': '55.849972125056624',
#    'long': '-4.310980546666565'}},
#  {'siteId': 'GD200A_S',
#   'from': {'description': 'Maryhill Road outbound to Great Western Road',
#    'lat': '55.87014169388683',
#    'long': '-4.268892500320476'},
#   'to': {'description': 'Maryhill Road outbound to Great Western Road',
#    'lat': '55.870462248447126',
#    'long': '-4.268079997790708'}},
#  {'siteId': 'GL1151_C',
#   'from': {'description': 'Dumbreck Road northbound to PRW / Dumbreck Rd',
#    'lat': '55.84921742483298',
#    'long': '-4.310488406707863'},
#   'to': {'description': 'Dumbreck Road northbound to PRW / Dumbreck Rd',
#    'lat': '55.84852706403615',
#    'long': '-4.309920225454224'}},
#  {'siteId': 'GD200A_R',
#   'from': {'description': 'Maryhill Road inbound towards G W R',
#    'lat': '55.872706993173516',
#    'long': '-4.269170047463331'},
#   'to': {'description': 'Maryhill Road inbound towards G W R',
#    'lat': '55.872895232727615',
#    'long': '-4.269197016816533'}},
#  {'siteId': 'GL1151_B',
#   'from': {'description': 'Paisley Road West westbound',
#    'lat': '55.85004788539256',
#    'long': '-4.309339470394715'},
#   'to': {'description': 'Paisley Road West westbound',
#    'lat': '55.849972125056624',
#    'long': '-4.310980546666565'}},
#  {'siteId': 'GL1151_A',
#   'from': {'description': 'Paisley Road West eastbound',
#    'lat': '55.849657571018625',
#    'long': '-4.311936424489083'},
#   'to': {'description': 'Paisley Road West eastbound',
#    'lat': '55.849972125056624',
#    'long': '-4.310980546666565'}},
#  {'siteId': 'GH312A_T',
#   'from': {'description': 's/b from Shawfield Dr from J2 / Poplin',
#    'lat': '55.84075769993983',
#    'long': '-4.227808021667737'},
#   'to': {'description': 's/b from Shawfield Dr from J2 / Poplin',
#    'lat': '55.83806956683952',
#    'long': '-4.231327608671311'}},
#  {'siteId': 'GA1301_B',
#   'from': {'description': 'Broomielaw westbound from York Street',
#    'lat': '55.85692922356656',
#    'long': '-4.265038089789566'},
#   'to': {'description': 'Broomielaw westbound from York Street',
#    'lat': '55.85686164638997',
#    'long': '-4.264315098440796'}},
#  {'siteId': 'GA1301_A',
#   'from': {'description': 'Broomielaw to York Street.',
#    'lat': '55.856959063447256',
#    'long': '-4.26390531049521'},
#   'to': {'description': 'Broomielaw to York Street.',
#    'lat': '55.85686164638997',
#    'long': '-4.264315098440796'}},
#  {'siteId': 'GD0651_W',
#   'from': {'description': 'Great Western Rd westbound R/T',
#    'lat': '55.888834293713586',
#    'long': '-4.321015152448036'},
#   'to': {'description': 'Great Western Rd westbound R/T',
#    'lat': '55.88870234315834',
#    'long': '-4.320863340913476'}},
#  {'siteId': 'GD0651_S',
#   'from': {'description': 'Great Western Road to Ascot Ave',
#    'lat': '55.88753559795142',
#    'long': '-4.317915128219077'},
#   'to': {'description': 'Great Western Road to Ascot Ave',
#    'lat': '55.887688516051426',
#    'long': '-4.317908255897963'}},
#  {'siteId': 'GD0651_R',
#   'from': {'description': 'Great Western Rd to Ascot Ave.',
#    'lat': '55.88922103772199',
#    'long': '-4.322429605710496'},
#   'to': {'description': 'Great Western Rd to Ascot Ave.',
#    'lat': '55.88923959554618',
#    'long': '-4.322398729442261'}},
#  {'siteId': 'GH312A_D',
#   'from': {'description': 'Shawfield Drive southbound to Clyde Walkway',
#    'lat': '55.84219933396287',
#    'long': '-4.226117518705436'},
#   'to': {'description': 'Shawfield Drive southbound to Clyde Walkway',
#    'lat': '55.84248518977821',
#    'long': '-4.226213727774215'}},
#  {'siteId': 'GB0751_V',
#   'from': {'description': 'Eglinton Street northbound to Cumberland St',
#    'lat': '55.84708106668321',
#    'long': '-4.2610144172166216'},
#   'to': {'description': 'Eglinton Street northbound to Cumberland St',
#    'lat': '55.84699480770674',
#    'long': '-4.260817707095752'}},
#  {'siteId': 'GB0751_T',
#   'from': {'description': 'Eglinton Street southbound to Cumberland Street',
#    'lat': '55.85049447586942',
#    'long': '-4.259647009961128'},
#   'to': {'description': 'Eglinton Street southbound to Cumberland Street',
#    'lat': '55.85063225821452',
#    'long': '-4.259974538694813'}},
#  {'siteId': 'GB0751_S',
#   'from': {'description': 'Cathcart Road to Cumberland Street',
#    'lat': '55.848209730275',
#    'long': '-4.255344777421482'},
#   'to': {'description': 'Cathcart Road to Cumberland Street',
#    'lat': '55.848092816760634',
#    'long': '-4.254858740826407'}},
#  {'siteId': 'GA4401_Y',
#   'from': {'description': 'Bus Station exit eastbound',
#    'lat': '55.86477919409067',
#    'long': '-4.249640707541476'},
#   'to': {'description': 'Bus Station exit eastbound',
#    'lat': '55.86471962992503',
#    'long': '-4.2489660093951676'}},
#  {'siteId': 'GA4401_Q',
#   'from': {'description': 'Killermont St westbound R/T from N. Hanover St',
#    'lat': '55.86455160575039',
#    'long': '-4.249307903173464'},
#   'to': {'description': 'Killermont St westbound R/T from N. Hanover St',
#    'lat': '55.86471962992503',
#    'long': '-4.2489660093951676'}},
#  {'siteId': 'GA4401_N',
#   'from': {'description': 'North Hanover St southbound to Killermont St',
#    'lat': '55.86535684098523',
#    'long': '-4.2485233737672115'},
#   'to': {'description': 'North Hanover St southbound to Killermont St',
#    'lat': '55.865470928123024',
#    'long': '-4.248673811036969'}},
#  {'siteId': 'GJ290A_N',
#   'from': {'description': 'Cathcart Rd northbound',
#    'lat': '55.83271790874834',
#    'long': '-4.2556932157246905'},
#   'to': {'description': 'Cathcart Rd northbound',
#    'lat': '55.83318476235378',
#    'long': '-4.255720253928153'}},
#  {'siteId': 'GA4401_M',
#   'from': {'description': 'North Hanover St northbound to Killermont St',
#    'lat': '55.8633899477641',
#    'long': '-4.249432518576116'},
#   'to': {'description': 'North Hanover St northbound to Killermont St',
#    'lat': '55.86325987773686',
#    'long': '-4.249664722294599'}},
#  {'siteId': 'GJ290A_M',
#   'from': {'description': 'Cathcart Rd southbound to Albert Rd',
#    'lat': '55.834909019823165',
#    'long': '-4.256283253088819'},
#   'to': {'description': 'Cathcart Rd southbound to Albert Rd',
#    'lat': '55.83514156835417',
#    'long': '-4.256344636200412'}},
#  {'siteId': 'GA4401_K',
#   'from': {'description': 'Killermont Street St eastbound to North Hanover St',
#    'lat': '55.86490099279722',
#    'long': '-4.252316796864651'},
#   'to': {'description': 'Killermont Street St eastbound to North Hanover St',
#    'lat': '55.865156707614595',
#    'long': '-4.2540577042514345'}},
#  {'siteId': 'GL2801_S',
#   'from': {'description': 'Govan Road westbound',
#    'lat': '55.85624527823334',
#    'long': '-4.285978514211548'},
#   'to': {'description': 'Govan Road westbound',
#    'lat': '55.855990477928046',
#    'long': '-4.28518058528346'}},
#  {'siteId': 'GL2801_R',
#   'from': {'description': 'Govan Road eastbound (f/l)',
#    'lat': '55.85624846009274',
#    'long': '-4.285323566368859'},
#   'to': {'description': 'Govan Road eastbound (f/l)',
#    'lat': '55.855990477928046',
#    'long': '-4.28518058528346'}},
#  {'siteId': 'GC155A_A',
#   'from': {'description': 'Dumbarton Road inbound to Western Inf.',
#    'lat': '55.870056548361696',
#    'long': '-4.2967326358773645'},
#   'to': {'description': 'Dumbarton Road inbound to Western Inf.',
#    'lat': '55.869880197121404',
#    'long': '-4.2955873194386385'}},
#  {'siteId': 'GL2801_B',
#   'from': {'description': 'Govan Road eastbound (F/L)',
#    'lat': '55.85651261150937',
#    'long': '-4.286585442207979'},
#   'to': {'description': 'Govan Road eastbound (F/L)',
#    'lat': '55.85644820814138',
#    'long': '-4.288115640401873'}},
#  {'siteId': 'GG267A_B',
#   'from': {'description': 'Shettleston Road to Blair Street',
#    'lat': '55.85223752966005',
#    'long': '-4.177962054873924'},
#   'to': {'description': 'Shettleston Road to Blair Street',
#    'lat': '55.852166048604',
#    'long': '-4.177430820965412'}},
#  {'siteId': 'GG267A_A',
#   'from': {'description': 'Shettleston Road to Blair Street',
#    'lat': '55.85274381385316',
#    'long': '-4.182863381641116'},
#   'to': {'description': 'Shettleston Road to Blair Street',
#    'lat': '55.852697985952794',
#    'long': '-4.18342000725699'}},
#  {'siteId': 'GA2101_C',
#   'from': {'description': 'West Regent Street eastbound',
#    'lat': '55.86264962734015',
#    'long': '-4.257955741740505'},
#   'to': {'description': 'West Regent Street eastbound',
#    'lat': '55.862642993422256',
#    'long': '-4.25782750543661'}},
#  {'siteId': 'GA2101_A',
#   'from': {'description': 'West Regent Street eastbound',
#    'lat': '55.86340326237511',
#    'long': '-4.259006331320647'},
#   'to': {'description': 'West Regent Street eastbound',
#    'lat': '55.86335752086073',
#    'long': '-4.257581303461147'}},
#  {'siteId': 'GK5141_R',
#   'from': {'description': 'Woodneuk Rd Southbound',
#    'lat': '55.81021478562821',
#    'long': '-4.352002772504004'},
#   'to': {'description': 'Woodneuk Rd Southbound',
#    'lat': '55.80986784958291',
#    'long': '-4.352285081796666'}},
#  {'siteId': 'GB1551_W',
#   'from': {'description': 'Westbound Right Turn into Camden Terrace',
#    'lat': '55.8464467938294',
#    'long': '-4.250514116570925'},
#   'to': {'description': 'Westbound Right Turn into Camden Terrace',
#    'lat': '55.84560870404568',
#    'long': '-4.250146178756491'}},
#  {'siteId': 'GL1821_X',
#   'from': {'description': 'Paisley Road West eastbound R/T',
#    'lat': '55.84534250908411',
#    'long': '-4.347575080845519'},
#   'to': {'description': 'Paisley Road West eastbound R/T',
#    'lat': '55.84569171226189',
#    'long': '-4.347644064242421'}},
#  {'siteId': 'GK5141_D',
#   'from': {'description': 'Nitshill Rd Eastbound to Glen Moriston',
#    'lat': '55.80760292836235',
#    'long': '-4.347584079369231'},
#   'to': {'description': 'Nitshill Rd Eastbound to Glen Moriston',
#    'lat': '55.80819435245893',
#    'long': '-4.349087964527667'}},
#  {'siteId': 'GL1821_V',
#   'from': {'description': 'Mosspark Drive',
#    'lat': '55.84540124604075',
#    'long': '-4.347323027783867'},
#   'to': {'description': 'Mosspark Drive',
#    'lat': '55.84569171226189',
#    'long': '-4.347644064242421'}},
#  {'siteId': 'GB1551_T',
#   'from': {'description': 'Camden Terrace',
#    'lat': '55.845897093956474',
#    'long': '-4.250594159531877'},
#   'to': {'description': 'Camden Terrace',
#    'lat': '55.84560870404568',
#    'long': '-4.250146178756491'}},
#  {'siteId': 'GB1551_S',
#   'from': {'description': 'Caledonia Rd westbound to Camden Terr',
#    'lat': '55.845226292576825',
#    'long': '-4.24894198294951'},
#   'to': {'description': 'Caledonia Rd westbound to Camden Terr',
#    'lat': '55.8451373881192',
#    'long': '-4.2488889245192105'}},
#  {'siteId': 'GK5141_B',
#   'from': {'description': 'Nitshill Rd Westbound',
#    'lat': '55.81071992563584',
#    'long': '-4.355193432458751'},
#   'to': {'description': 'Nitshill Rd Westbound',
#    'lat': '55.81086661759488',
#    'long': '-4.35504269022466'}},
#  {'siteId': 'GD1451_F',
#   'from': {'description': 'Southbrae Drive Eastbound',
#    'lat': '55.88337934350126',
#    'long': '-4.328124888674801'},
#   'to': {'description': 'Southbrae Drive Eastbound',
#    'lat': '55.88368793243936',
#    'long': '-4.326064624857545'}},
#  {'siteId': 'GL1821_S',
#   'from': {'description': 'Paisley Road West westbound to Mosspark Dr',
#    'lat': '55.84550045400156',
#    'long': '-4.344006265387408'},
#   'to': {'description': 'Paisley Road West westbound to Mosspark Dr',
#    'lat': '55.84574649238161',
#    'long': '-4.3438293824379475'}},
#  {'siteId': 'GD1451_E',
#   'from': {'description': 'Crow Road Southbound RT',
#    'lat': '55.883185799690786',
#    'long': '-4.3260025982811054'},
#   'to': {'description': 'Crow Road Southbound RT',
#    'lat': '55.88368793243936',
#    'long': '-4.326064624857545'}},
#  {'siteId': 'GL1821_R',
#   'from': {'description': 'Paisley Road West eastbound',
#    'lat': '55.84575359406552',
#    'long': '-4.349580753000242'},
#   'to': {'description': 'Paisley Road West eastbound',
#    'lat': '55.84569171226189',
#    'long': '-4.347644064242421'}},
#  {'siteId': 'GD1451_D',
#   'from': {'description': 'Crow Road Southbound', 'lat': '0', 'long': '0'},
#   'to': {'description': 'Crow Road Southbound', 'lat': '0', 'long': '0'}},
#  {'siteId': 'GD1451_C',
#   'from': {'description': 'Crow Road Northbound',
#    'lat': '55.883771144626195',
#    'long': '-4.325941681104589'},
#   'to': {'description': 'Crow Road Northbound',
#    'lat': '55.88537132047088',
#    'long': '-4.325445764623142'}},
#  {'siteId': 'GI0601_W',
#   'from': {'description': 'M74 off-ramp eastbound inside',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'M74 off-ramp eastbound inside',
#    'lat': '55.838280729980546',
#    'long': '-4.240475302309936'}},
#  {'siteId': 'GI0601_V',
#   'from': {'description': 'Polmadie Rd northbound to M74 eastbound',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Polmadie Rd northbound to M74 eastbound',
#    'lat': '55.837623810988134',
#    'long': '-4.24150756825777'}},
#  {'siteId': 'GG2151_V',
#   'from': {'description': 'Bellgrove St northbound',
#    'lat': '55.85774784916511',
#    'long': '-4.224610058030884'},
#   'to': {'description': 'Bellgrove St northbound',
#    'lat': '55.85820833060708',
#    'long': '-4.2244925690859905'}},
#  {'siteId': 'GI0601_T',
#   'from': {'description': 'Polmadie Road southbound to M74 eastbound',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Polmadie Road southbound to M74 eastbound',
#    'lat': '55.83840070086405',
#    'long': '-4.239316294000794'}},
#  {'siteId': 'GG2151_T',
#   'from': {'description': 'Westercraig southbound (one way SB)',
#    'lat': '55.85870411586409',
#    'long': '-4.223913685680131'},
#   'to': {'description': 'Westercraig southbound (one way SB)',
#    'lat': '55.85820833060708',
#    'long': '-4.2244925690859905'}},
#  {'siteId': 'GG2151_S',
#   'from': {'description': 'Duke St. eastbound to Bellgrove',
#    'lat': '55.859012506786335',
#    'long': '-4.229715996716747'},
#   'to': {'description': 'Duke St. eastbound to Bellgrove',
#    'lat': '55.858936631359896',
#    'long': '-4.229935365584897'}},
#  {'siteId': 'GI0601_R',
#   'from': {'description': 'M74 off-ramp eastbound outside',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'M74 off-ramp eastbound outside',
#    'lat': '55.838280729980546',
#    'long': '-4.240475302309936'}},
#  {'siteId': 'GG2151_R',
#   'from': {'description': 'Duke St. westbound',
#    'lat': '55.85833640316464',
#    'long': '-4.221383888355596'},
#   'to': {'description': 'Duke St. westbound',
#    'lat': '55.85828743430807',
#    'long': '-4.221109441773829'}},
#  {'siteId': 'GK0501_D',
#   'from': {'description': 'Pollokshaws Road outbound to Minard Road',
#    'lat': '55.83394260631425',
#    'long': '-4.274592372020509'},
#   'to': {'description': 'Pollokshaws Road outbound to Minard Road',
#    'lat': '55.83432823150459',
#    'long': '-4.274151768372783'}},
#  {'siteId': 'GK0501_C',
#   'from': {'description': 'Pollokshaws Road inbound to Minard Road',
#    'lat': '55.83075213023767',
#    'long': '-4.280410174073082'},
#   'to': {'description': 'Pollokshaws Road inbound to Minard Road',
#    'lat': '55.83022560271131',
#    'long': '-4.281177758397061'}},
#  {'siteId': 'GK0501_B',
#   'from': {'description': 'Langside Avenue',
#    'lat': '55.830898484503535',
#    'long': '-4.277847819660646'},
#   'to': {'description': 'Langside Avenue',
#    'lat': '55.83155999993093',
#    'long': '-4.278525255393111'}},
#  {'siteId': 'GK0501_A',
#   'from': {'description': 'Minard Road',
#    'lat': '55.83195553710533',
#    'long': '-4.2794905592678285'},
#   'to': {'description': 'Minard Road',
#    'lat': '55.83155999993093',
#    'long': '-4.278525255393111'}},
#  {'siteId': 'GH338B_A',
#   'from': {'description': 'Dalmarnock Road eastbound to Birkwood St. EB',
#    'lat': '55.84045286681901',
#    'long': '-4.213830922680041'},
#   'to': {'description': 'Dalmarnock Road eastbound to Birkwood St. EB',
#    'lat': '55.840448271219856',
#    'long': '-4.214086215304658'}},
#  {'siteId': 'GF215A_V',
#   'from': {'description': 'Cumbernauld Rd northbound to Naver St',
#    'lat': '55.869265181955654',
#    'long': '-4.190295905938847'},
#   'to': {'description': 'Cumbernauld Rd northbound to Naver St',
#    'lat': '55.86916841037575',
#    'long': '-4.190178569819827'}},
#  {'siteId': 'GA5201_D',
#   'from': {'description': 'High St southbound to Bell St',
#    'lat': '55.858870241145745',
#    'long': '-4.241500914430377'},
#   'to': {'description': 'High St southbound to Bell St',
#    'lat': '55.85898462824174',
#    'long': '-4.24163534267433'}},
#  {'siteId': 'GF215A_T',
#   'from': {'description': 'Cumbernauld Rd southbound to Naver St',
#    'lat': '55.872800026631786',
#    'long': '-4.185587493418333'},
#   'to': {'description': 'Cumbernauld Rd southbound to Naver St',
#    'lat': '55.87289491528983',
#    'long': '-4.185305090000423'}},
#  {'siteId': 'GA5201_B',
#   'from': {'description': 'Bell St westbound',
#    'lat': '55.857289491404686',
#    'long': '-4.2419371685787635'},
#   'to': {'description': 'Bell St westbound',
#    'lat': '55.857593538264496',
#    'long': '-4.242513960854066'}},
#  {'siteId': 'GA5201_A',
#   'from': {'description': 'Bell St eastbound',
#    'lat': '55.85783410821877',
#    'long': '-4.243614422514919'},
#   'to': {'description': 'Bell St eastbound',
#    'lat': '55.857593538264496',
#    'long': '-4.242513960854066'}},
#  {'siteId': 'GB0141_V',
#   'from': {'description': 'West Street to Wallace St northbound outside lanes',
#    'lat': '55.851648048670604',
#    'long': '-4.265337856755604'},
#   'to': {'description': 'West Street to Wallace St northbound outside lanes',
#    'lat': '55.85158947840783',
#    'long': '-4.2655900781266585'}},
#  {'siteId': 'GB0141_U',
#   'from': {'description': 'West Street to Wallace St northbound inside lane',
#    'lat': '55.85166453475065',
#    'long': '-4.265418700971182'},
#   'to': {'description': 'West Street to Wallace St northbound inside lane',
#    'lat': '55.85158947840783',
#    'long': '-4.2655900781266585'}},
#  {'siteId': 'GA1551_J',
#   'from': {'description': 'Argyle Street w/b from Oswald Street',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Argyle Street w/b from Oswald Street',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GG2581_F',
#   'from': {'description': 'Shettleston Road westbound to Duke St inside lane',
#    'lat': '55.85463829456522',
#    'long': '-4.1965987463374566'},
#   'to': {'description': 'Shettleston Road westbound to Duke St inside lane',
#    'lat': '55.85507451899186',
#    'long': '-4.1978377008337'}},
#  {'siteId': 'GK5051_T',
#   'from': {'description': 'Kyleakin Road Southbound',
#    'lat': '55.803446829332714',
#    'long': '-4.331727431547246'},
#   'to': {'description': 'Kyleakin Road Southbound',
#    'lat': '55.802872682850285',
#    'long': '-4.332618614081079'}},
#  {'siteId': 'GK5051_S',
#   'from': {'description': 'Nitshill Rd Westbound to M77',
#    'lat': '55.802960643090685',
#    'long': '-4.332719619718705'},
#   'to': {'description': 'Nitshill Rd Westbound to M77',
#    'lat': '55.802872682850285',
#    'long': '-4.332618614081079'}},
#  {'siteId': 'GG2581_C',
#   'from': {'description': 'Duke St. to Duke St East',
#    'lat': '55.85352498428161',
#    'long': '-4.1975424875028144'},
#   'to': {'description': 'Duke St. to Duke St East',
#    'lat': '55.85347866716663',
#    'long': '-4.197619759233908'}},
#  {'siteId': 'GK5051_R',
#   'from': {'description': 'Nitshill Rd Eastbound to Loganswell Rd',
#    'lat': '55.802829705590845',
#    'long': '-4.332041584373695'},
#   'to': {'description': 'Nitshill Rd Eastbound to Loganswell Rd',
#    'lat': '55.802872682850285',
#    'long': '-4.332618614081079'}},
#  {'siteId': 'GG2581_B',
#   'from': {'description': 'Shettleston Road westbound to Duke St outside lane',
#    'lat': '55.85466551443288',
#    'long': '-4.196584304821799'},
#   'to': {'description': 'Shettleston Road westbound to Duke St outside lane',
#    'lat': '55.85507451899186',
#    'long': '-4.1978377008337'}},
#  {'siteId': 'GL1301_T',
#   'from': {'description': 'Paisley Road West westbound',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Paisley Road West westbound',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GG2581_A',
#   'from': {'description': 'Shettleston Road eastbound to Duke St East',
#    'lat': '55.85532646700769',
#    'long': '-4.198826597978703'},
#   'to': {'description': 'Shettleston Road eastbound to Duke St East',
#    'lat': '55.855537380135324',
#    'long': '-4.199094167081915'}},
#  {'siteId': 'GL1301_S',
#   'from': {'description': 'Jura St', 'lat': '0', 'long': '0'},
#   'to': {'description': 'Jura St', 'lat': '0', 'long': '0'}},
#  {'siteId': 'GL1301_R',
#   'from': {'description': 'Paisley Road West eastbound',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Paisley Road West eastbound',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GD2251_S',
#   'from': {'description': 'Maryhill Road outbound towards Fire Station',
#    'lat': '55.88073133287157',
#    'long': '-4.275090597183299'},
#   'to': {'description': 'Maryhill Road outbound towards Fire Station',
#    'lat': '55.88085188241169',
#    'long': '-4.27488979510388'}},
#  {'siteId': 'GH337A_B',
#   'from': {'description': 'Dalmarnock Road westbound to Birkwood St',
#    'lat': '55.83854202944291',
#    'long': '-4.210639820452077'},
#   'to': {'description': 'Dalmarnock Road westbound to Birkwood St',
#    'lat': '55.838817486281165',
#    'long': '-4.210815172545751'}},
#  {'siteId': 'GD2251_R',
#   'from': {'description': 'Maryhill Road inbound to Fire Station',
#    'lat': '55.88412038865245',
#    'long': '-4.280389856662116'},
#   'to': {'description': 'Maryhill Road inbound to Fire Station',
#    'lat': '55.884272417997686',
#    'long': '-4.280430756019544'}},
#  {'siteId': 'GK4591_B',
#   'from': {'description': 'Crookston Rd northbound',
#    'lat': '55.830131053641765',
#    'long': '-4.363281369101331'},
#   'to': {'description': 'Crookston Rd northbound',
#    'lat': '55.82978431166565',
#    'long': '-4.363084679123617'}},
#  {'siteId': 'GK4591_A',
#   'from': {'description': 'Crookston Rd southbound',
#    'lat': '55.82517130267535',
#    'long': '-4.363204018408259'},
#   'to': {'description': 'Crookston Rd southbound',
#    'lat': '55.82519424957813',
#    'long': '-4.363412974588296'}},
#  {'siteId': 'GL2621_T',
#   'from': {'description': 'Govan Rd Northbound',
#    'lat': '55.85527973642665',
#    'long': '-4.29728252494175'},
#   'to': {'description': 'Govan Rd Northbound',
#    'lat': '55.85534127437887',
#    'long': '-4.295912000825322'}},
#  {'siteId': 'GC0051_G',
#   'from': {'description': 'Elderslie Street North',
#    'lat': '55.86387922610634',
#    'long': '-4.275607258691609'},
#   'to': {'description': 'Elderslie Street North',
#    'lat': '55.86298912434018',
#    'long': '-4.275139671119664'}},
#  {'siteId': 'GA4651_V',
#   'from': {'description': 'Gorbals Street n/b to Victoria Bridge',
#    'lat': '55.85232937827657',
#    'long': '-4.252707611714965'},
#   'to': {'description': 'Gorbals Street n/b to Victoria Bridge',
#    'lat': '55.851641793066776',
#    'long': '-4.252955398146887'}},
#  {'siteId': 'GC0051_F',
#   'from': {'description': 'Elderslie Street South',
#    'lat': '55.862322996481275',
#    'long': '-4.275196603969021'},
#   'to': {'description': 'Elderslie Street South',
#    'lat': '55.86298912434018',
#    'long': '-4.275139671119664'}},
#  {'siteId': 'GC0051_E',
#   'from': {'description': 'St Vincent Street West to Elderslie St',
#    'lat': '55.86305638424973',
#    'long': '-4.271499789957201'},
#   'to': {'description': 'St Vincent Street West to Elderslie St',
#    'lat': '55.863004166197506',
#    'long': '-4.26994652479772'}},
#  {'siteId': 'GA4651_T',
#   'from': {'description': 'Stockwell Street Southbound',
#    'lat': '55.855578694138686',
#    'long': '-4.249987620993227'},
#   'to': {'description': 'Stockwell Street Southbound',
#    'lat': '55.85544548450444',
#    'long': '-4.2499000269930995'}},
#  {'siteId': 'GC0051_D',
#   'from': {'description': 'Argyle Street to Elderslie Street',
#    'lat': '55.86338219860943',
#    'long': '-4.279637561166447'},
#   'to': {'description': 'Argyle Street to Elderslie Street',
#    'lat': '55.86335655106783',
#    'long': '-4.280051584897541'}},
#  {'siteId': 'GA0571_V',
#   'from': {'description': 'Douglas St Northbound from Cadogan St',
#    'lat': '55.860225861048335',
#    'long': '-4.265134118419911'},
#   'to': {'description': 'Douglas St Northbound from Cadogan St',
#    'lat': '55.86071079831662',
#    'long': '-4.26466695088232'}},
#  {'siteId': 'GA4651_S',
#   'from': {'description': 'Clyde Street westbound to Stockwell St',
#    'lat': '55.85408462969502',
#    'long': '-4.249613639611782'},
#   'to': {'description': 'Clyde Street westbound to Stockwell St',
#    'lat': '55.85306846618108',
#    'long': '-4.2466949406691255'}},
#  {'siteId': 'GA4651_R',
#   'from': {'description': 'Clyde Street Eastbound',
#    'lat': '55.854849793412924',
#    'long': '-4.251511339891655'},
#   'to': {'description': 'Clyde Street Eastbound',
#    'lat': '55.85459359919607',
#    'long': '-4.250777504302567'}},
#  {'siteId': 'GG1171_D',
#   'from': {'description': 'Stepps Road NB R/T into Gartloch Rd (E)',
#    'lat': '55.87144147137224',
#    'long': '-4.158688848927345'},
#   'to': {'description': 'Stepps Road NB R/T into Gartloch Rd (E)',
#    'lat': '55.8713589959702',
#    'long': '-4.15929168603979'}},
#  {'siteId': 'GG1171_C',
#   'from': {'description': 'Stepps Road',
#    'lat': '52.26705443478302',
#    'long': '-3.978915403761452'},
#   'to': {'description': 'Stepps Road',
#    'lat': '55.8713589959702',
#    'long': '-4.15929168603979'}},
#  {'siteId': 'GG1171_B',
#   'from': {'description': 'Gartloch Road (E)',
#    'lat': '55.87140410787499',
#    'long': '-4.157232175344292'},
#   'to': {'description': 'Gartloch Road (E)',
#    'lat': '55.8713589959702',
#    'long': '-4.15929168603979'}},
#  {'siteId': 'GG1171_A',
#   'from': {'description': 'Borthwick Street',
#    'lat': '55.871039713323285',
#    'long': '-4.160073183625248'},
#   'to': {'description': 'Borthwick Street',
#    'lat': '55.8713589959702',
#    'long': '-4.15929168603979'}},
#  {'siteId': 'GA0571_N',
#   'from': {'description': 'Waterloo St Westbound inside to Douglas St',
#    'lat': '55.86070723971057',
#    'long': '-4.263883692348966'},
#   'to': {'description': 'Waterloo St Westbound inside to Douglas St',
#    'lat': '55.86074562868264',
#    'long': '-4.263262680588069'}},
#  {'siteId': 'GD0801_C',
#   'from': {'description': 'Lynedoch Street',
#    'lat': '55.86856661921254',
#    'long': '-4.273883500913411'},
#   'to': {'description': 'Lynedoch Street',
#    'lat': '55.86859136135907',
#    'long': '-4.273517317222294'}},
#  {'siteId': 'GD0801_A',
#   'from': {'description': 'Woodlands Road Southbound to Lynedoch Street',
#    'lat': '55.86921845642285',
#    'long': '-4.274113419119813'},
#   'to': {'description': 'Woodlands Road Southbound to Lynedoch Street',
#    'lat': '55.86859136135907',
# ...
#   'to': {'description': 'Bilsland Drive',
#    'lat': '55.886541465689234',
#    'long': '-4.256800832635375'}},
#  {'siteId': 'GE0301_T',
#   'from': {'description': 'Balmore Road outbound towards Hawthorn Street',
#    'lat': '55.88537610015535',
#    'long': '-4.25663722825672'},
#   'to': {'description': 'Balmore Road outbound towards Hawthorn Street',
#    'lat': '55.885282615637884',
#    'long': '-4.256343968236027'}},
#  {'siteId': 'GE0301_S',
#   'from': {'description': 'Hawthorn Street',
#    'lat': '55.886564601291575',
#    'long': '-4.255538867901006'},
#   'to': {'description': 'Hawthorn Street',
#    'lat': '55.886541465689234',
#    'long': '-4.256800832635375'}},
#  {'siteId': 'GE0301_R',
#   'from': {'description': 'Balmore Rd inbound towards Hawthorn St',
#    'lat': '55.89068099986828',
#    'long': '-4.258960363041584'},
#   'to': {'description': 'Balmore Rd inbound towards Hawthorn St',
#    'lat': '55.890818780368626',
#    'long': '-4.259288231746152'}},
#  {'siteId': 'GD260A_B',
#   'from': {'description': 'Maryhill Road outbound towards Sandbank Street',
#    'lat': '55.89110456999437',
#    'long': '-4.290987350024925'},
#   'to': {'description': 'Maryhill Road outbound towards Sandbank Street',
#    'lat': '55.890529884306325',
#    'long': '-4.289993891196285'}},
#  {'siteId': 'GD260A_A',
#   'from': {'description': 'Maryhill Road inbound towards Sandbank Street',
#    'lat': '55.89347400383256',
#    'long': '-4.296948945976821'},
#   'to': {'description': 'Maryhill Road inbound towards Sandbank Street',
#    'lat': '55.89394772975637',
#    'long': '-4.2970889096571705'}},
#  {'siteId': 'GD030A_S',
#   'from': {'description': 'GWR to Cecil St',
#    'lat': '55.876502925859334',
#    'long': '-4.285506649293601'},
#   'to': {'description': 'GWR to Cecil St',
#    'lat': '55.87641522514137',
#    'long': '-4.28538958413702'}},
#  {'siteId': 'GD030A_R',
#   'from': {'description': 'GWR to Cecil St.',
#    'lat': '55.87765798836764',
#    'long': '-4.289123814393541'},
#   'to': {'description': 'GWR to Cecil St.',
#    'lat': '55.87777179017829',
#    'long': '-4.2897700247368356'}},
#  {'siteId': 'GH0101_B',
#   'from': {'description': 'Gallowgate west to Barrack St',
#    'lat': '55.85537253283011',
#    'long': '-4.226743188856404'},
#   'to': {'description': 'Gallowgate west to Barrack St',
#    'lat': '55.85526881737797',
#    'long': '-4.2260182328994995'}},
#  {'siteId': 'GH0101_A',
#   'from': {'description': 'Gallowgate east to Barrack St.',
#    'lat': '55.855506997151515',
#    'long': '-4.234692132089879'},
#   'to': {'description': 'Gallowgate east to Barrack St.',
#    'lat': '55.855840661390054',
#    'long': '-4.232650064049586'}},
#  {'siteId': 'GA4151_V',
#   'from': {'description': 'Queen St.',
#    'lat': '55.86116829908267',
#    'long': '-4.251493436028325'},
#   'to': {'description': 'Queen St.',
#    'lat': '55.8616195332612',
#    'long': '-4.251391701174512'}},
#  {'siteId': 'GB0401_X',
#   'from': {'description': 'Clyde Place to Commerce Street eastbound outside lane',
#    'lat': '55.85513382354682',
#    'long': '-4.2619935727729565'},
#   'to': {'description': 'Clyde Place to Commerce Street eastbound outside lane',
#    'lat': '55.85476337655625',
#    'long': '-4.25965520363947'}},
#  {'siteId': 'GB0401_V',
#   'from': {'description': 'Commerce Street northbound to Clyde Place',
#    'lat': '55.85401868549479',
#    'long': '-4.26007532256916'},
#   'to': {'description': 'Commerce Street northbound to Clyde Place',
#    'lat': '55.8537771620326',
#    'long': '-4.260013363076228'}},
#  {'siteId': 'GC4051_F',
#   'from': {'description': 'Congress Road Inside to Congress Way',
#    'lat': '55.8590140293683',
#    'long': '-4.284495236395233'},
#   'to': {'description': 'Congress Road Inside to Congress Way',
#    'lat': '55.85864141064304',
#    'long': '-4.284233660871131'}},
#  {'siteId': 'GC4051_D',
#   'from': {'description': 'Congress Way Southbound to Congress Rd',
#    'lat': '55.859280521632435',
#    'long': '-4.283695896232739'},
#   'to': {'description': 'Congress Way Southbound to Congress Rd',
#    'lat': '55.85935619571898',
#    'long': '-4.283492595662314'}},
#  {'siteId': 'GB0401_R',
#   'from': {'description': 'Clyde Place to Commerce Street eastbound',
#    'lat': '55.855188277845784',
#    'long': '-4.2619647812568875'},
#   'to': {'description': 'Clyde Place to Commerce Street eastbound',
#    'lat': '55.85476337655625',
#    'long': '-4.25965520363947'}},
#  {'siteId': 'GC4051_B',
#   'from': {'description': 'Finnieston Quay eastbound to S.E.C.C',
#    'lat': '55.857841346257544',
#    'long': '-4.2818217217682'},
#   'to': {'description': 'Finnieston Quay eastbound to S.E.C.C',
#    'lat': '55.85774831166304',
#    'long': '-4.2819920405285306'}},
#  {'siteId': 'GC4051_A',
#   'from': {'description': 'Congress Road Outside to Congress Way',
#    'lat': '55.85899459169434',
#    'long': '-4.284573995247211'},
#   'to': {'description': 'Congress Road Outside to Congress Way',
#    'lat': '55.85864141064304',
#    'long': '-4.284233660871131'}},
#  {'siteId': 'GK4851_S',
#   'from': {'description': 'Crookston Rd northbound',
#    'lat': '55.83248638394767',
#    'long': '-4.362785508685784'},
#   'to': {'description': 'Crookston Rd northbound',
#    'lat': '55.83239976472467',
#    'long': '-4.363083672970994'}},
#  {'siteId': 'GH320A_B',
#   'from': {'description': 'Dalmarnock Road westbound to Dale St',
#    'lat': '55.844682621217736',
#    'long': '-4.219997746293337'},
#   'to': {'description': 'Dalmarnock Road westbound to Dale St',
#    'lat': '55.844494367966725',
#    'long': '-4.21997103772343'}},
#  {'siteId': 'GH320A_A',
#   'from': {'description': 'Dalmarnock Road eastbound to Dale St',
#    'lat': '55.8459831505471',
#    'long': '-4.221637402893596'},
#   'to': {'description': 'Dalmarnock Road eastbound to Dale St',
#    'lat': '55.845487003307056',
#    'long': '-4.221241682068287'}},
#  {'siteId': 'GA2701_D',
#   'from': {'description': 'Renfield street southbound to Bath Street',
#    'lat': '55.864391257964655',
#    'long': '-4.255611563952369'},
#   'to': {'description': 'Renfield street southbound to Bath Street',
#    'lat': '55.864353004607004',
#    'long': '-4.2557372027795095'}},
#  {'siteId': 'GA2701_B',
#   'from': {'description': 'Bath Street westbound from West Nile St',
#    'lat': '55.86360948968639',
#    'long': '-4.254623310621573'},
#   'to': {'description': 'Bath Street westbound from West Nile St',
#    'lat': '55.863845557995276',
#    'long': '-4.255963489217906'}},
#  {'siteId': 'GD1621_A',
#   'from': {'description': 'Great Western Rd to Anniesland Cross',
#    'lat': '55.89193614888848',
#    'long': '-4.329517157091596'},
#   'to': {'description': 'Great Western Rd to Anniesland Cross',
#    'lat': '55.891609635960464',
#    'long': '-4.329673514038679'}},
#  {'siteId': 'GA0401_T',
#   'from': {'description': 'Elmbank St',
#    'lat': '55.86395258867079',
#    'long': '-4.268227863465616'},
#   'to': {'description': 'Elmbank St',
#    'lat': '55.86512927308056',
#    'long': '-4.268264508431323'}},
#  {'siteId': 'GA0401_S',
#   'from': {'description': 'St Vincent Street Westbound',
#    'lat': '55.862545696704125',
#    'long': '-4.266052272953681'},
#   'to': {'description': 'St Vincent Street Westbound',
#    'lat': '55.86257394307593',
#    'long': '-4.265494568722255'}},
#  {'siteId': 'GA0401_R',
#   'from': {'description': 'St Vincent Street East to Elmbank St',
#    'lat': '55.86305832768834',
#    'long': '-4.269933703376354'},
#   'to': {'description': 'St Vincent Street East to Elmbank St',
#    'lat': '55.863004166197506',
#    'long': '-4.26994652479772'}},
#  {'siteId': 'GC120A_G',
#   'from': {'description': 'Argyle Street towards Kelvingrove Street',
#    'lat': '55.86510999051392',
#    'long': '-4.2853326955192514'},
#   'to': {'description': 'Argyle Street towards Kelvingrove Street',
#    'lat': '55.86528999934927',
#    'long': '-4.286286244928538'}},
#  {'siteId': 'GA5471_D',
#   'from': {'description': 'Motorway off ramp Castle St. southbound',
#    'lat': '55.865429441247834',
#    'long': '-4.236157121242562'},
#   'to': {'description': 'Motorway off ramp Castle St. southbound',
#    'lat': '55.8648959825708',
#    'long': '-4.235838776125701'}},
#  {'siteId': 'GA5471_C',
#   'from': {'description': 'Castle St. northbound',
#    'lat': '55.86402333571597',
#    'long': '-4.23687539121088'},
#   'to': {'description': 'Castle St. northbound',
#    'lat': '55.86401203541582',
#    'long': '-4.237002596556166'}},
#  {'siteId': 'GA5471_B',
#   'from': {'description': 'Castle Street to Ramp C',
#    'lat': '55.8661546764245',
#    'long': '-4.234824293822307'},
#   'to': {'description': 'Castle Street to Ramp C',
#    'lat': '55.86610225828142',
#    'long': '-4.234741368662251'}},
#  {'siteId': 'GC1631_X',
#   'from': {'description': 'Hayburn St nearside',
#    'lat': '55.86866138186298',
#    'long': '-4.310764187114153'},
#   'to': {'description': 'Hayburn St nearside',
#    'lat': '55.86929848850435',
#    'long': '-4.3108180231697855'}},
#  {'siteId': 'GC1631_W',
#   'from': {'description': 'Meadow Road',
#    'lat': '55.86919639352558',
#    'long': '-4.3119468443932005'},
#   'to': {'description': 'Meadow Road',
#    'lat': '55.86929848850435',
#    'long': '-4.3108180231697855'}},
#  {'siteId': 'GC1631_V',
#   'from': {'description': 'Hayburn St offside',
#    'lat': '55.86865988245911',
#    'long': '-4.310844018539943'},
#   'to': {'description': 'Hayburn St offside',
#    'lat': '55.86929848850435',
#    'long': '-4.3108180231697855'}},
#  {'siteId': 'GH4521_F',
#   'from': {'description': 'Fullarton Road s/b',
#    'lat': '55.835999692078374',
#    'long': '-4.172246863649164'},
#   'to': {'description': 'Fullarton Road s/b',
#    'lat': '55.836126235853115',
#    'long': '-4.172206011428887'}},
#  {'siteId': 'GJ0351_D',
#   'from': {'description': 'Aikenhead Road southbound to Menock Rd',
#    'lat': '55.82017210003487',
#    'long': '-4.250257546433559'},
#   'to': {'description': 'Aikenhead Road southbound to Menock Rd',
#    'lat': '55.82016283016515',
#    'long': '-4.2502729750640285'}},
#  {'siteId': 'GH4521_E',
#   'from': {'description': 'M74  e/b off ramp',
#    'lat': '55.83637722366697',
#    'long': '-4.173769128718611'},
#   'to': {'description': 'M74  e/b off ramp',
#    'lat': '55.836126235853115',
#    'long': '-4.172206011428887'}},
#  {'siteId': 'GJ0351_C',
#   'from': {'description': 'Aikenhead Road northbound',
#    'lat': '55.818430366496436',
#    'long': '-4.25015697041314'},
#   'to': {'description': 'Aikenhead Road northbound',
#    'lat': '55.82640363492185',
#    'long': '-4.246641817951074'}},
#  {'siteId': 'GC1631_R',
#   'from': {'description': 'Expressway Off-Ramp eastbound',
#    'lat': '55.86875616935264',
#    'long': '-4.312416185365758'},
#   'to': {'description': 'Expressway Off-Ramp eastbound',
#    'lat': '55.86929848850435',
#    'long': '-4.3108180231697855'}},
#  {'siteId': 'GJ0351_B',
#   'from': {'description': 'Menock Road westbound',
#    'lat': '55.81909085486535',
#    'long': '-4.248933992022725'},
#   'to': {'description': 'Menock Road westbound',
#    'lat': '55.81929977405216',
#    'long': '-4.250286990737608'}},
#  {'siteId': 'GJ0351_A',
#   'from': {'description': 'Menock Road eastbound',
#    'lat': '55.81924802421207',
#    'long': '-4.25164090617372'},
#   'to': {'description': 'Menock Road eastbound',
#    'lat': '55.82640363492185',
#    'long': '-4.246641817951074'}},
#  {'siteId': 'GH4521_B',
#   'from': {'description': 'Fullarton Roundabout s/b circulatory',
#    'lat': '55.83561735383645',
#    'long': '-4.170995850302077'},
#   'to': {'description': 'Fullarton Roundabout s/b circulatory',
#    'lat': '55.83494562438461',
#    'long': '-4.171373617863877'}},
#  {'siteId': 'GK0251_V',
#   'from': {'description': 'Pollokshaws Road inbound to Albert Drive',
#    'lat': '55.838800480265775',
#    'long': '-4.267529161607213'},
#   'to': {'description': 'Pollokshaws Road inbound to Albert Drive',
#    'lat': '55.83834658561153',
#    'long': '-4.267774245631587'}},
#  {'siteId': 'GK0251_T',
#   'from': {'description': 'Pollokshaws Road outbound to Albert Drive',
#    'lat': '55.84228274564642',
#    'long': '-4.263403260149433'},
#   'to': {'description': 'Pollokshaws Road outbound to Albert Drive',
#    'lat': '55.84235897320175',
#    'long': '-4.263168095042885'}},
#  {'siteId': 'GK0251_R',
#   'from': {'description': 'Albert Drive R/T',
#    'lat': '55.84115074735943',
#    'long': '-4.266308360823459'},
#   'to': {'description': 'Albert Drive R/T',
#    'lat': '55.84071743316437',
#    'long': '-4.265436600315468'}},
#  {'siteId': 'GG2751_D',
#   'from': {'description': 'South Chester Street',
#    'lat': '55.85075040392315',
#    'long': '-4.169555246772373'},
#   'to': {'description': 'South Chester Street',
#    'lat': '55.85177087994107',
#    'long': '-4.169276620816412'}},
#  {'siteId': 'GG2751_B',
#   'from': {'description': 'Shettleston Road to Chester St',
#    'lat': '55.85157937320951',
#    'long': '-4.166374199723624'},
#   'to': {'description': 'Shettleston Road to Chester St',
#    'lat': '55.85153701060594',
#    'long': '-4.166228053507993'}},
#  {'siteId': 'GG2751_A',
#   'from': {'description': 'Shettleston Rd East to Chester St',
#    'lat': '55.85183299613021',
#    'long': '-4.171868295482324'},
#   'to': {'description': 'Shettleston Rd East to Chester St',
#    'lat': '55.85191037902376',
#    'long': '-4.172575586561228'}},
#  {'siteId': 'GG0021_H',
#   'from': {'description': 'Alexandra Parade R/T to Wishart Street',
#    'lat': '55.86560326028364',
#    'long': '-4.229054889727144'},
#   'to': {'description': 'Alexandra Parade R/T to Wishart Street',
#    'lat': '55.86566957783804',
#    'long': '-4.228866899377545'}},
#  {'siteId': 'GG0021_C',
#   'from': {'description': 'Wishart Street',
#    'lat': '55.86537274202822',
#    'long': '-4.229872766495637'},
#   'to': {'description': 'Wishart Street',
#    'lat': '55.86566957783804',
#    'long': '-4.228866899377545'}},
#  {'siteId': 'GG0021_B',
#   'from': {'description': 'Alexandra Parade westbound to Wishart Street',
#    'lat': '55.865421633821946',
#    'long': '-4.227669993143565'},
#   'to': {'description': 'Alexandra Parade westbound to Wishart Street',
#    'lat': '55.86566957783804',
#    'long': '-4.228866899377545'}},
#  {'siteId': 'GB1201_E',
#   'from': {'description': 'Cathcart Road northbound',
#    'lat': '55.84687582162568',
#    'long': '-4.255059820284952'},
#   'to': {'description': 'Cathcart Road northbound',
#    'lat': '55.848092816760634',
#    'long': '-4.254858740826407'}},
#  {'siteId': 'GG0021_A',
#   'from': {'description': 'Alexandra Parade eastbound to Wishart Street',
#    'lat': '55.86627401191743',
#    'long': '-4.234191837483145'},
#   'to': {'description': 'Alexandra Parade eastbound to Wishart Street',
#    'lat': '55.86610225828142',
#    'long': '-4.234741368662251'}},
#  {'siteId': 'GL1901_T',
#   'from': {'description': 'Hillington Road southbound right turn',
#    'lat': '55.8465731249378',
#    'long': '-4.359822404393915'},
#   'to': {'description': 'Hillington Road southbound right turn',
#    'lat': '55.84552155892677',
#    'long': '-4.359822556890798'}},
#  {'siteId': 'GL1901_S',
#   'from': {'description': 'PRW to Hillington Road',
#    'lat': '55.84579511370658',
#    'long': '-4.355398116477264'},
#   'to': {'description': 'PRW to Hillington Road',
#    'lat': '55.84596178260748',
#    'long': '-4.354673352933915'}},
#  {'siteId': 'GB1201_A',
#   'from': {'description': 'Cumberland Street',
#    'lat': '55.84836128637019',
#    'long': '-4.256391968423523'},
#   'to': {'description': 'Cumberland Street',
#    'lat': '55.848092816760634',
#    'long': '-4.254858740826407'}},
#  {'siteId': 'GL1901_P',
#   'from': {'description': 'Hillington Road southbound left turn',
#    'lat': '55.84657373725236',
#    'long': '-4.359790491046517'},
#   'to': {'description': 'Hillington Road southbound left turn',
#    'lat': '55.84552155892677',
#    'long': '-4.359822556890798'}},
#  {'siteId': 'GE0551_S',
#   'from': {'description': 'Balmore Road outbound',
#    'lat': '55.89565126752435',
#    'long': '-4.26383987505431'},
#   'to': {'description': 'Balmore Road outbound',
#    'lat': '55.89557340592638',
#    'long': '-4.263675388864068'}},
#  {'siteId': 'GE0551_R',
#   'from': {'description': 'Balmore Road inbound towards Skirsa St',
#    'lat': '55.89864459845293',
#    'long': '-4.266253765163888'},
#   'to': {'description': 'Balmore Road inbound towards Skirsa St',
#    'lat': '55.897546071428856',
#    'long': '-4.266365642948926'}},
#  ...]

# %%
# convert to a dataframe
sensors_df = pd.DataFrame.from_dict(pd.json_normalize(sensor_data), orient = 'columns')
sensors_df
# Out:
#         siteId                               from.description  \
# 0     GH020A_B                    Gallowgate west to Sword St
# 1     GJ3301_D                       Carmunnock Rd southbound
# 2     GH020A_A                    Gallowgate east to Sword St
# 3     GJ3301_C  Carmunnock Rd northbound to Kings Park Avenue
# 4     GJ3301_B      Kings Park Ave westbound to Carmunnock Rd
# ...        ...                                            ...
# 1270  GL1851_S                        PRW from tweedsmuir w/b
# 1271  GJ011A_V          Aikenhead Road northbound to Dixon Rd
# 1272  GA4771_V                    Glassford Street Northbound
# 1273  GJ011A_T          Aikenhead Road southbound to Dixon Rd
# 1274  GA4771_T                    Glassford Street Southbound
#
#                 from.lat            from.long  \
# 0       55.8543754827825   -4.217259197086495
# 1     55.821736212748405  -4.2561270616272875
# 2      55.85539015389372   -4.225769520669405
# 3      55.81925458152306   -4.255696036412074
# 4     55.820288451422314   -4.250775113480551
# ...                  ...                  ...
# 1270  55.845768181789424   -4.355396486903399
# 1271   55.83169902330712   -4.248512176194785
# 1272  55.857648657839455    -4.24934030262111
# 1273  55.835226792673474   -4.248747790943153
# 1274   55.85969518557228   -4.248499802037326
#
#                                      to.description              to.lat  \
# 0                       Gallowgate west to Sword St  55.854434529999814
# 1                          Carmunnock Rd southbound   55.82105417976632
# 2                       Gallowgate east to Sword St   55.85526881737797
# 3     Carmunnock Rd northbound to Kings Park Avenue   55.81849086854625
# 4         Kings Park Ave westbound to Carmunnock Rd   55.82016283016515
# ...                                             ...                 ...
# 1270                        PRW from tweedsmuir w/b   55.84552155892677
# 1271          Aikenhead Road northbound to Dixon Rd   55.83150931858993
# 1272                    Glassford Street Northbound   55.85741063079249
# 1273          Aikenhead Road southbound to Dixon Rd  55.835572558348154
# 1274                    Glassford Street Southbound   55.85987416120498
#
#                   to.long
# 0      -4.216974959509279
# 1       -4.25607160697339
# 2     -4.2260182328994995
# 3      -4.255683756017223
# 4     -4.2502729750640285
# ...                   ...
# 1270   -4.359822556890798
# 1271   -4.248565099314686
# 1272   -4.249086854965875
# 1273   -4.249007310223754
# 1274   -4.248542105351628
#
# [1275 rows x 7 columns]

# %%
# keep only spatial attributes

keep_cols = ['siteId', 'from.lat', 'from.long']
sensors_df = sensors_df[keep_cols]
sensors_df

# change attribute names
sensors_df = sensors_df.rename(columns={'from.lat': 'lat', 'from.long': 'long'})
sensors_df
# Out:
#         siteId                 lat                 long
# 0     GH020A_B    55.8543754827825   -4.217259197086495
# 1     GJ3301_D  55.821736212748405  -4.2561270616272875
# 2     GH020A_A   55.85539015389372   -4.225769520669405
# 3     GJ3301_C   55.81925458152306   -4.255696036412074
# 4     GJ3301_B  55.820288451422314   -4.250775113480551
# ...        ...                 ...                  ...
# 1270  GL1851_S  55.845768181789424   -4.355396486903399
# 1271  GJ011A_V   55.83169902330712   -4.248512176194785
# 1272  GA4771_V  55.857648657839455    -4.24934030262111
# 1273  GJ011A_T  55.835226792673474   -4.248747790943153
# 1274  GA4771_T   55.85969518557228   -4.248499802037326
#
# [1275 rows x 3 columns]

# %%
# convert to geodataframe
gdf_sensors = gpd.GeoDataFrame(sensors_df, geometry=gpd.points_from_xy(sensors_df['long'], sensors_df['lat']), crs = "EPSG:4326")

# map the sensors
gdf_sensors.explore()

# there are some spatial outliers due to missing or incorrectly recorded locations, 
# but these will be clipped out in the next step when the spatial join is performed

# %% [markdown]
# ### Map screenshot
#
# ![Map](map2.png)

# %%
# load workplace_zones shapefile

workzones = gpd.read_file('workplace_zones/WorkplaceZones2011Scotland.shp')
workzones = workzones.to_crs("EPSG:4326")
workzones.head()
# Out:
#        LADCD       WZCD                                           geometry
# 0  S12000040  S34005373  POLYGON ((-3.53075 55.88204, -3.53071 55.88204...
# 1  S12000033  S34000001  POLYGON ((-2.10886 57.14376, -2.10894 57.14374...
# 2  S12000033  S34000002  POLYGON ((-2.10811 57.14525, -2.10801 57.14515...
# 3  S12000033  S34000003  POLYGON ((-2.09785 57.14710, -2.09757 57.14690...
# 4  S12000033  S34000004  POLYGON ((-2.09783 57.14760, -2.09780 57.14738...

# %%
# perform spatial join

gdf_clipped = gpd.sjoin(gdf_sensors, workzones, how='inner') # point in polygon

# %%
gdf_clipped.explore()

# %% [markdown]
# ### Map screenshot
#
# ![Map](map3.png)

# %%
gdf_clipped.head()
# Out:
#      siteId                 lat                 long  \
# 0  GH020A_B    55.8543754827825   -4.217259197086495
# 1  GJ3301_D  55.821736212748405  -4.2561270616272875
# 2  GH020A_A   55.85539015389372   -4.225769520669405
# 3  GJ3301_C   55.81925458152306   -4.255696036412074
# 4  GJ3301_B  55.820288451422314   -4.250775113480551
#
#                     geometry  index_right      LADCD       WZCD
# 0  POINT (-4.21726 55.85438)         4834  S12000046  S34004861
# 1  POINT (-4.25613 55.82174)         4940  S12000046  S34004978
# 2  POINT (-4.22577 55.85539)         5163  S12000046  S34005204
# 3  POINT (-4.25570 55.81925)         4928  S12000046  S34004966
# 4  POINT (-4.25078 55.82029)         4811  S12000046  S34004838

# %%
# calculate sensors by workzone

sensors_byWZ = gdf_clipped.groupby(["WZCD"]).size()
sensors_byWZ = pd.DataFrame(sensors_byWZ, columns = ['sensor_count'])
sensors_byWZ.head()
# Out:
#            sensor_count
# WZCD
# S34000363             1
# S34000365             1
# S34000367             5
# S34000368             2
# S34000370             5

# %%
# merge dataframes
merged_gdf = workzones.merge(sensors_byWZ, on='WZCD')
merged_gdf
# Out:
#          LADCD       WZCD                                           geometry  \
# 0    S12000046  S34000365  POLYGON ((-4.27158 55.86770, -4.27154 55.86767...
# 1    S12000046  S34000367  POLYGON ((-4.25858 55.85750, -4.25902 55.85751...
# 2    S12000046  S34000368  POLYGON ((-4.26175 55.86113, -4.26181 55.86090...
# 3    S12000046  S34000370  POLYGON ((-4.24515 55.86513, -4.24461 55.86515...
# 4    S12000046  S34000372  POLYGON ((-4.17205 55.83641, -4.17186 55.83610...
# ..         ...        ...                                                ...
# 335  S12000046  S34004927  POLYGON ((-4.28278 55.85286, -4.28280 55.85258...
# 336  S12000046  S34000450  POLYGON ((-4.25168 55.86155, -4.25172 55.86141...
# 337  S12000046  S34005045  POLYGON ((-4.26366 55.85605, -4.26378 55.85581...
# 338  S12000046  S34005147  POLYGON ((-4.26185 55.87438, -4.26282 55.87406...
# 339  S12000046  S34000408  POLYGON ((-4.25989 55.86186, -4.25929 55.86178...
#
#      sensor_count
# 0               1
# 1               5
# 2               2
# 3               5
# 4               5
# ..            ...
# 335             1
# 336             2
# 337             4
# 338             4
# 339             6
#
# [340 rows x 4 columns]

# %%
merged_gdf.explore(column='sensor_count', cmap='Blues')

# %% [markdown]
# ### Map screenshot
#
# ![Map](map4.png)
